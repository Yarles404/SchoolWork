# %%
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# alc.head()

# %%
alc.loc[(alc['continent'] == 'Europe') & (alc['beer_servings'] > 50), ['country']]
# countries in Europe with beer_servings > 50
# Out:
#                 country
# 1               Albania
# 3               Andorra
# 9               Austria
# 15              Belarus
# 16              Belgium
# 21   Bosnia-Herzegovina
# 25             Bulgaria
# 42              Croatia
# 44               Cyprus
# 45       Czech Republic
# 48              Denmark
# 57              Estonia
# 60              Finland
# 61               France
# 64              Georgia
# 65              Germany
# 67               Greece
# 75              Hungary
# 76              Iceland
# 81              Ireland
# 83                Italy
# 93               Latvia
# 98            Lithuania
# 99           Luxembourg
# 105               Malta
# 120         Netherlands
# 126              Norway
# 135              Poland
# 136            Portugal
# 139             Moldova
# 140             Romania
# 151              Serbia
# 155            Slovakia
# 156            Slovenia
# 160               Spain
# 165              Sweden
# 166         Switzerland
# ...

# %%
default = alc.groupby(['continent']).size()
default.plot.bar()
# default bar chart

# %%
alc.groupby(['continent']).describe()
# Out:
#               beer_servings                                              \
#                       count        mean        std   min     25%    50%
# continent
# Africa                 53.0   61.471698  80.557816   0.0   15.00   32.0
# Asia                   44.0   37.045455  49.469725   0.0    4.25   17.5
# Europe                 45.0  193.777778  99.631569   0.0  127.00  219.0
# North America          23.0  145.434783  79.621163   1.0   80.00  143.0
# Oceania                16.0   89.687500  96.641412   0.0   21.00   52.5
# South America          12.0  175.083333  65.242845  93.0  129.50  162.5
#
#                              spirit_servings              ... wine_servings  \
#                   75%    max           count        mean  ...           75%
# continent                                                 ...
# Africa          76.00  376.0            53.0   16.339623  ...         13.00
# Asia            60.50  247.0            44.0   60.840909  ...          8.00
# ...

# %%
beer_servings = alc.groupby(['continent']).beer_servings.mean()
beer_servings.plot.bar()
# bar chart of beer_servings mean by continent

# %%
alc.boxplot(column = 'beer_servings', by = 'continent')
# boxplot of beer_servings by continent
